# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
traffic_data=pd.read_csv("Traffic_processed.csv")

# %%
traffic_data.head(100)
# Out:
#     Location_Easting_OSGR  Location_Northing_OSGR  Longitude   Latitude  \
# 0                525680.0                178240.0  -0.191170  51.489096
# 1                524170.0                181650.0  -0.211708  51.520075
# 2                524520.0                182240.0  -0.206458  51.525301
# 3                526900.0                177530.0  -0.173862  51.482442
# 4                528060.0                179040.0  -0.156618  51.495752
# 5                524770.0                181160.0  -0.203238  51.515540
# 6                524220.0                180830.0  -0.211277  51.512695
# 7                525890.0                179710.0  -0.187623  51.502260
# 8                527350.0                177650.0  -0.167342  51.483420
# 9                524550.0                180810.0  -0.206531  51.512443
# 10               526240.0                178900.0  -0.182872  51.494902
# 11               526170.0                177690.0  -0.184312  51.484044
# ...

# %%
traffic_data_columns = traffic_data.columns.values.tolist()
print('The {} columns are:\n'.format( len(traffic_data_columns) ))

for mdc in traffic_data_columns:
    print(mdc)
# Out:
# The 16 columns are:
#
# Location_Easting_OSGR
# Location_Northing_OSGR
# Longitude
# Latitude
# Accident_Severity
# Number_of_Vehicles
# Number_of_Casualties
# Date
# Day_of_Week
# Time
# Road_Type
# Speed_limit
# Light_Conditions
# Weather_Conditions
# Road_Surface_Conditions
# Year
