# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
traffic_data = pd.read_csv("Traffic-Flow-Accidents/data/accidents_2005_to_2007.csv")
# Out:
# D:\Anaconda\lib\site-packages\IPython\core\interactiveshell.py:2698: DtypeWarning: Columns (31) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
traffic_data.head(100)
# Out:
#    Accident_Index  Location_Easting_OSGR  Location_Northing_OSGR  Longitude  \
# 0   200501BS00001               525680.0                178240.0  -0.191170
# 1   200501BS00002               524170.0                181650.0  -0.211708
# 2   200501BS00003               524520.0                182240.0  -0.206458
# 3   200501BS00004               526900.0                177530.0  -0.173862
# 4   200501BS00005               528060.0                179040.0  -0.156618
# 5   200501BS00006               524770.0                181160.0  -0.203238
# 6   200501BS00007               524220.0                180830.0  -0.211277
# 7   200501BS00009               525890.0                179710.0  -0.187623
# 8   200501BS00010               527350.0                177650.0  -0.167342
# 9   200501BS00011               524550.0                180810.0  -0.206531
# 10  200501BS00012               526240.0                178900.0  -0.182872
# ...

# %%
traffic_data_columns = traffic_data.columns.values.tolist()
print('The {} columns are:\n'.format( len(traffic_data_columns) ))

for mdc in traffic_data_columns:
    print(mdc)
# Out:
# The 33 columns are:
#
# Accident_Index
# Location_Easting_OSGR
# Location_Northing_OSGR
# Longitude
# Latitude
# Police_Force
# Accident_Severity
# Number_of_Vehicles
# Number_of_Casualties
# Date
# Day_of_Week
# Time
# Local_Authority_(District)
# Local_Authority_(Highway)
# 1st_Road_Class
# 1st_Road_Number
# Road_Type
# Speed_limit
# Junction_Detail
# Junction_Control
# 2nd_Road_Class
# 2nd_Road_Number
# Pedestrian_Crossing-Human_Control
# Pedestrian_Crossing-Physical_Facilities
# Light_Conditions
# Weather_Conditions
# Road_Surface_Conditions
# Special_Conditions_at_Site
# Carriageway_Hazards
# Urban_or_Rural_Area
# Did_Police_Officer_Attend_Scene_of_Accident
# LSOA_of_Accident_Location
# Year

# %%
print('Traffic Dataset has {} rows'.format( len(traffic_data) ))
# Out:
# Traffic Dataset has 570011 rows

# %%
traffic_data.isnull().any()
# Out:
# Accident_Index                                 False
# Location_Easting_OSGR                           True
# Location_Northing_OSGR                          True
# Longitude                                       True
# Latitude                                        True
# Police_Force                                   False
# Accident_Severity                              False
# Number_of_Vehicles                             False
# Number_of_Casualties                           False
# Date                                           False
# Day_of_Week                                    False
# Time                                            True
# Local_Authority_(District)                     False
# Local_Authority_(Highway)                      False
# 1st_Road_Class                                 False
# 1st_Road_Number                                False
# Road_Type                                      False
# Speed_limit                                    False
# ...

# %%
traffic_data.fillna("")
# Out:
#        Accident_Index Location_Easting_OSGR Location_Northing_OSGR Longitude  \
# 0       200501BS00001                525680                 178240  -0.19117
# 1       200501BS00002                524170                 181650 -0.211708
# 2       200501BS00003                524520                 182240 -0.206458
# 3       200501BS00004                526900                 177530 -0.173862
# 4       200501BS00005                528060                 179040 -0.156618
# 5       200501BS00006                524770                 181160 -0.203238
# 6       200501BS00007                524220                 180830 -0.211277
# 7       200501BS00009                525890                 179710 -0.187623
# 8       200501BS00010                527350                 177650 -0.167342
# 9       200501BS00011                524550                 180810 -0.206531
# 10      200501BS00012                526240                 178900 -0.182872
# ...

# %%
traffic_data.dropna(axis=0, how='all')
# Out:
#        Accident_Index  Location_Easting_OSGR  Location_Northing_OSGR  \
# 0       200501BS00001               525680.0                178240.0
# 1       200501BS00002               524170.0                181650.0
# 2       200501BS00003               524520.0                182240.0
# 3       200501BS00004               526900.0                177530.0
# 4       200501BS00005               528060.0                179040.0
# 5       200501BS00006               524770.0                181160.0
# 6       200501BS00007               524220.0                180830.0
# 7       200501BS00009               525890.0                179710.0
# 8       200501BS00010               527350.0                177650.0
# 9       200501BS00011               524550.0                180810.0
# 10      200501BS00012               526240.0                178900.0
# 11      200501BS00014               526170.0                177690.0
# 12      200501BS00015               525590.0                178520.0
# ...

# %%
traffic_data2 = pd.read_csv ("Traffic-Flow-Accidents/data/accidents_2009_to_2011.csv")

# %%
traffic_data2
# Out:
#        Accident_Index  Location_Easting_OSGR  Location_Northing_OSGR  \
# 0       200901BS70001                 524910                  180800
# 1       200901BS70002                 525050                  181040
# 2       200901BS70003                 526490                  177990
# 3       200901BS70004                 524800                  180300
# 4       200901BS70005                 526930                  177490
# 5       200901BS70006                 526060                  178730
# 6       200901BS70007                 526580                  177270
# 7       200901BS70008                 526550                  178580
# 8       200901BS70009                 527310                  179100
# 9       200901BS70010                 526250                  177370
# 10      200901BS70011                 526930                  177490
# 11      200901BS70012                 526230                  178910
# 12      200901BS70015                 524570                  179290
# ...

# %%
traffic_data["Police_Force"].sort_values(ascending=False)
# Out:
# 570010    98
# 387590    98
# 387578    98
# 387579    98
# 387580    98
# 387581    98
# 387582    98
# 387583    98
# 387584    98
# 387585    98
# 387586    98
# 387587    98
# 387588    98
# 387589    98
# 387591    98
# 387547    98
# 387592    98
# 387593    98
# 387594    98
# 387595    98
# 387596    98
# 387597    98
# 387598    98
# 387599    98
# 387600    98
# 387601    98
# 387602    98
# 387603    98
# 387577    98
# 387576    98
#           ..
# 391333     1
# 391343     1
# 391332     1
# 391331     1
# 391330     1
# 391329     1
# 391328     1
# 391327     1
# 391326     1
# 391342     1
# 391344     1
# 391362     1
# 391354     1
# 391361     1
# 391360     1
# 391359     1
# 391358     1
# 391357     1
# 391356     1
# 391355     1
# 391353     1
# 391345     1
# 391352     1
# 391351     1
# 391350     1
# 391349     1
# 391348     1
# 391347     1
# 391346     1
# 0          1
# Name: Police_Force, Length: 570011, dtype: int64

# %%
traffic_data3= pd.read_csv ("Traffic-Flow-Accidents/data/accidents_2012_to_2014.csv")
# Out:
# D:\Anaconda\lib\site-packages\IPython\core\interactiveshell.py:2698: DtypeWarning: Columns (31) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
traffic_data3.head(50)
# Out:
#    Accident_Index  Location_Easting_OSGR  Location_Northing_OSGR  Longitude  \
# 0   201201BS70001                 527200                  178760  -0.169101
# 1   201201BS70002                 524930                  181430  -0.200838
# 2   201201BS70003                 525860                  178080  -0.188636
# 3   201201BS70004                 524980                  181030  -0.200259
# 4   201201BS70005                 526170                  179200  -0.183773
# 5   201201BS70006                 526090                  177600  -0.185496
# 6   201201BS70007                 527780                  179680  -0.160418
# 7   201201BS70008                 524010                  182080  -0.213862
# 8   201201BS70010                 527710                  179290  -0.161567
# 9   201201BS70011                 525120                  180060  -0.198587
# 10  201201BS70012                 525720                  179680  -0.190082
# ...

# %%
traffic_data2["Number_of_Vehicles"].sort_values(ascending=False)
# Out:
# 445474    34
# 144875    32
# 374998    29
# 202016    19
# 46762     16
# 202641    14
# 56428     14
# 194985    13
# 265184    13
# 231499    13
# 204882    13
# 46763     13
# 285067    12
# 371258    12
# 154343    12
# 127025    12
# 200179    12
# 134779    11
# 347546    11
# 455658    11
# 204695    11
# 106701    11
# 218710    11
# 224567    11
# 331841    11
# 365759    11
# 195863    11
# 429248    11
# 202023    10
# 348499    10
#           ..
# 228916     1
# 228914     1
# 228978     1
# 228983     1
# 229052     1
# 228988     1
# 229049     1
# 229046     1
# 229045     1
# 229044     1
# 229042     1
# 229041     1
# 229040     1
# 229039     1
# 229037     1
# 229036     1
# 229030     1
# 229029     1
# 229025     1
# 229023     1
# 229019     1
# 229018     1
# 229014     1
# 229010     1
# 229003     1
# 229001     1
# 228997     1
# 228994     1
# 228989     1
# 234720     1
# Name: Number_of_Vehicles, Length: 469442, dtype: int64

# %%
traffic_data4= pd.read_csv ("Traffic-Flow-Accidents/data/ukTrafficAADF.csv")

# %%
traffic_data4.head(50)
# Out:
#     AADFYear    CP Estimation_method  \
# 0       2000  6007           Counted
# 1       2000  6009           Counted
# 2       2000  6035           Counted
# 3       2000  6054           Counted
# 4       2000  6055           Counted
# 5       2000  6056           Counted
# 6       2000  6057         Estimated
# 7       2000  6063           Counted
# 8       2000  6066           Counted
# 9       2000  6088           Counted
# 10      2000  6089           Counted
# 11      2000  6222         Estimated
# 12      2000  6232           Counted
# 13      2000  6233           Counted
# 14      2000  6234           Counted
# 15      2000  6565         Estimated
# 16      2000  6576           Counted
# 17      2000  6577         Estimated
# 18      2000  6578           Counted
# 19      2000  6580           Counted
# 20      2000  6587           Counted
# 21      2000  6593           Counted
# 22      2000  6595         Estimated
# 23      2000  6604         Estimated
# ...

# %%
traffic_data4_columns = traffic_data4.columns.values.tolist()
print('The {} columns are:\n'.format( len(traffic_data4_columns) ))

for mdc in traffic_data4_columns:
    print(mdc)
# Out:
# The 29 columns are:
#
# AADFYear
# CP
# Estimation_method
# Estimation_method_detailed
# Region
# LocalAuthority
# Road
# RoadCategory
# Easting
# Northing
# StartJunction
# EndJunction
# LinkLength_km
# LinkLength_miles
# PedalCycles
# Motorcycles
# CarsTaxis
# BusesCoaches
# LightGoodsVehicles
# V2AxleRigidHGV
# V3AxleRigidHGV
# V4or5AxleRigidHGV
# V3or4AxleArticHGV
# V5AxleArticHGV
# V6orMoreAxleArticHGV
# AllHGVs
# AllMotorVehicles
# Lat
# Lon

# %%
traffic_data4["PedalCycles"].sort_values(ascending=False)
# Out:
# 134876    18629
# 137221    17619
# 139579    17394
# 132535    16889
# 141935    16880
# 130188    16788
# 127841    16771
# 144290    15692
# 219827    13814
# 219130    12722
# 218001    11844
# 215471    11402
# 219524    11086
# 220861    10938
# 219753    10938
# 205411    10910
# 217299    10757
# 201741    10751
# 203574    10633
# 220794    10037
# 220357    10037
# 220612    10037
# 216413     9521
# 216173     9489
# 217927     9379
# 219039     9379
# 123145     9378
# 216099     9275
# 217212     9275
# 196483     9199
#           ...
# 27018         0
# 27017         0
# 27016         0
# 106899        0
# 106900        0
# 106916        0
# 106922        0
# 27006         0
# 27005         0
# 27004         0
# 106923        0
# 106869        0
# 106865        0
# 106855        0
# 106802        0
# 106770        0
# 106773        0
# 106781        0
# 106787        0
# 106793        0
# 106794        0
# 106808        0
# 106854        0
# 106815        0
# ...

# %%
traffic_data.drop( ['Accident_Index',"Special_Conditions_at_Site"], axis=1)
# Out:
#         Location_Easting_OSGR  Location_Northing_OSGR  Longitude   Latitude  \
# 0                    525680.0                178240.0  -0.191170  51.489096
# 1                    524170.0                181650.0  -0.211708  51.520075
# 2                    524520.0                182240.0  -0.206458  51.525301
# 3                    526900.0                177530.0  -0.173862  51.482442
# 4                    528060.0                179040.0  -0.156618  51.495752
# 5                    524770.0                181160.0  -0.203238  51.515540
# 6                    524220.0                180830.0  -0.211277  51.512695
# 7                    525890.0                179710.0  -0.187623  51.502260
# 8                    527350.0                177650.0  -0.167342  51.483420
# 9                    524550.0                180810.0  -0.206531  51.512443
# 10                   526240.0                178900.0  -0.182872  51.494902
# ...

# %%
traffic_data = traffic_data.drop( ['Accident_Index',"Special_Conditions_at_Site","Special_Conditions_at_Site"], axis=1)

# %%
frames = [df,df1]

# %%
result= pd.concat(frames)

# %%
result['Light_Conditions_Modified'] = result['Light_Conditions'].str.split(":")

# %%
result
# Out:
#         1st_Road_Class  1st_Road_Number  2nd_Road_Class  2nd_Road_Number  \
# 0                  3.0           3218.0            -1.0              0.0
# 1                  4.0            450.0             5.0              0.0
# 2                  5.0              0.0            -1.0              0.0
# 3                  3.0           3220.0            -1.0              0.0
# 4                  6.0              0.0            -1.0              0.0
# 5                  6.0              0.0            -1.0              0.0
# 6                  5.0              0.0             6.0              0.0
# 7                  3.0            315.0            -1.0              0.0
# 8                  3.0           3212.0             4.0            304.0
# 9                  4.0            450.0             5.0              0.0
# 10                 3.0              4.0             4.0            325.0
# 11                 3.0           3220.0             3.0            308.0
# ...

# %%
result['Light_Conditions_Modified_One'] = result['Light_Conditions_Modified'].apply( lambda x: x[0] )

# %%
result
# Out:
#         1st_Road_Class  1st_Road_Number  2nd_Road_Class  2nd_Road_Number  \
# 0                  3.0           3218.0            -1.0              0.0
# 1                  4.0            450.0             5.0              0.0
# 2                  5.0              0.0            -1.0              0.0
# 3                  3.0           3220.0            -1.0              0.0
# 4                  6.0              0.0            -1.0              0.0
# 5                  6.0              0.0            -1.0              0.0
# 6                  5.0              0.0             6.0              0.0
# 7                  3.0            315.0            -1.0              0.0
# 8                  3.0           3212.0             4.0            304.0
# 9                  4.0            450.0             5.0              0.0
# 10                 3.0              4.0             4.0            325.0
# 11                 3.0           3220.0             3.0            308.0
# ...

# %%
result.drop(['Test'], axis=1)
# Out:
#         1st_Road_Class  1st_Road_Number  2nd_Road_Class  2nd_Road_Number  \
# 0                  3.0           3218.0            -1.0              0.0
# 1                  4.0            450.0             5.0              0.0
# 2                  5.0              0.0            -1.0              0.0
# 3                  3.0           3220.0            -1.0              0.0
# 4                  6.0              0.0            -1.0              0.0
# 5                  6.0              0.0            -1.0              0.0
# 6                  5.0              0.0             6.0              0.0
# 7                  3.0            315.0            -1.0              0.0
# 8                  3.0           3212.0             4.0            304.0
# 9                  4.0            450.0             5.0              0.0
# 10                 3.0              4.0             4.0            325.0
# 11                 3.0           3220.0             3.0            308.0
# ...

# %%
result.info()

# %%
result['Time'].fillna("00:00", inplace=True)
def getTime(s):
        (h, m) = s.split(':')
        result = int(h) * 3600 + int(m) * 60
        return str(int(result))

# %%
result['TimeInt'] = result['Time'].apply( lambda x: getTime(x) )

# %%
result
